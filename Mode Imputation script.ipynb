# %%
import pandas as pd
import glob

def Average_files(participant_num):
    # Find all files for the given participant number
    file_pattern = f"*participant_{participant_num}_trial_*"
    file_list = glob.glob(file_pattern)

    # Create an empty dataframe to store the aggregated data
    participant_data = pd.DataFrame()

       # Loop through all files for the participant
    for file_name in file_list:
        # Load the file as a pandas dataframe
        df = pd.read_csv(file_name)

        # Remove the specified columns
        columns_to_remove = ['Unnamed: 0','Participant name', 'Computer timestamp', 'Sensor', 'Project name', 
                      'Export date', 'Recording name','Recording date',  'Recording date UTC',  'Validity left',
       'Validity right', 'Recording start time UTC','Recording start time', 'Recording duration', 'Timeline name', 'Recording Fixation filter name', 
                      'Recording software version', 'Recording resolution height', 'Recording resolution width', 
                      'Recording monitor latency', 'Eyetracker timestamp', 'Event', 'Event value','Presented Stimulus name', 'Presented Media name','Eye movement type']
        df = df.drop(columns=columns_to_remove)

        # convert all columns to float64 by checking the column data type
        for col in df.columns:
            if df[col].dtype != 'float64':
                if df[col].dtype == 'object':
                    df[col] = df[col].str.replace(',', '.')
                try:
                    df[col] = pd.to_numeric(df[col], errors='raise').astype('float64')
                except:
                    continue

        # Add a 'Participant_Number' column to the dataframe
        df['Participant_Number'] = participant_num

        # Calculate the mode of the remaining columns
        modes = df.mode()

        # Add a row to the participant data with the modes
        participant_data = participant_data.append(modes.iloc[0], ignore_index=True)

    # Write the participant data to a new CSV file
    output_file_name = f"participant_{participant_num}_data.csv"
    participant_data.to_csv(output_file_name, index=False)
    print(df.info())

# Loop through all participants and process their files
for participant_num in range(1, 61):
    Average_files(participant_num)
# Out:
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4522 entries, 0 to 4521
# Data columns (total 46 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Recording timestamp                  4522 non-null   float64
#  1   Gaze point X                         4522 non-null   float64
#  2   Gaze point Y                         4522 non-null   float64
#  3   Gaze point left X                    4522 non-null   float64
#  4   Gaze point left Y                    4522 non-null   float64
#  5   Gaze point right X                   4522 non-null   float64
#  6   Gaze point right Y                   4522 non-null   float64
#  7   Gaze direction left X                4522 non-null   float64
#  8   Gaze direction left Y                4522 non-null   float64
#  9   Gaze direction left Z                4522 non-null   float64
#  10  Gaze direction right X               4522 non-null   float64
#  11  Gaze direction right Y               4522 non-null   float64
#  12  Gaze direction right Z               4522 non-null   float64
#  13  Pupil diameter left                  4522 non-null   float64
#  14  Pupil diameter right                 4522 non-null   float64
#  15  Eye position left X (DACSmm)         4522 non-null   float64
#  16  Eye position left Y (DACSmm)         4522 non-null   float64
#  17  Eye position left Z (DACSmm)         4522 non-null   float64
#  18  Eye position right X (DACSmm)        4522 non-null   float64
#  19  Eye position right Y (DACSmm)        4522 non-null   float64
#  20  Eye position right Z (DACSmm)        4522 non-null   float64
#  21  Gaze point left X (DACSmm)           4522 non-null   float64
#  22  Gaze point left Y (DACSmm)           4522 non-null   float64
#  23  Gaze point right X (DACSmm)          4522 non-null   float64
#  24  Gaze point right Y (DACSmm)          4522 non-null   float64
#  25  Gaze point X (MCSnorm)               4522 non-null   float64
#  26  Gaze point Y (MCSnorm)               4522 non-null   float64
#  27  Gaze point left X (MCSnorm)          4522 non-null   float64
#  28  Gaze point left Y (MCSnorm)          4522 non-null   float64
#  29  Gaze point right X (MCSnorm)         4522 non-null   float64
#  30  Gaze point right Y (MCSnorm)         4522 non-null   float64
#  31  Presented Media width                4522 non-null   float64
#  32  Presented Media height               4522 non-null   float64
#  33  Presented Media position X (DACSpx)  4522 non-null   float64
#  34  Presented Media position Y (DACSpx)  4522 non-null   float64
#  35  Original Media width                 4522 non-null   float64
#  36  Original Media height                4522 non-null   float64
#  37  Gaze event duration                  4522 non-null   float64
#  38  Eye movement type index              4522 non-null   float64
#  39  Fixation point X                     4522 non-null   float64
#  40  Fixation point Y                     4522 non-null   float64
#  41  Fixation point X (MCSnorm)           4522 non-null   float64
#  42  Fixation point Y (MCSnorm)           4522 non-null   float64
#  43  Mouse position X                     4522 non-null   float64
#  44  Mouse position Y                     4522 non-null   float64
#  45  Participant_Number                   4522 non-null   int64
# dtypes: float64(45), int64(1)
# memory usage: 1.6 MB
# None
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26771 entries, 0 to 26770
# Data columns (total 46 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Recording timestamp                  26771 non-null  float64
#  1   Gaze point X                         26771 non-null  float64
#  2   Gaze point Y                         26771 non-null  float64
#  3   Gaze point left X                    26771 non-null  float64
#  4   Gaze point left Y                    26771 non-null  float64
#  5   Gaze point right X                   26771 non-null  float64
#  6   Gaze point right Y                   26771 non-null  float64
#  7   Gaze direction left X                26771 non-null  float64
#  8   Gaze direction left Y                26771 non-null  float64
#  9   Gaze direction left Z                26771 non-null  float64
#  10  Gaze direction right X               26771 non-null  float64
#  11  Gaze direction right Y               26771 non-null  float64
#  12  Gaze direction right Z               26771 non-null  float64
#  13  Pupil diameter left                  26771 non-null  float64
#  14  Pupil diameter right                 26771 non-null  float64
#  15  Eye position left X (DACSmm)         26771 non-null  float64
#  16  Eye position left Y (DACSmm)         26771 non-null  float64
#  17  Eye position left Z (DACSmm)         26771 non-null  float64
#  18  Eye position right X (DACSmm)        26771 non-null  float64
#  19  Eye position right Y (DACSmm)        26771 non-null  float64
#  20  Eye position right Z (DACSmm)        26771 non-null  float64
#  21  Gaze point left X (DACSmm)           26771 non-null  float64
#  22  Gaze point left Y (DACSmm)           26771 non-null  float64
#  23  Gaze point right X (DACSmm)          26771 non-null  float64
#  24  Gaze point right Y (DACSmm)          26771 non-null  float64
#  25  Gaze point X (MCSnorm)               26771 non-null  float64
#  26  Gaze point Y (MCSnorm)               26771 non-null  float64
#  27  Gaze point left X (MCSnorm)          26771 non-null  float64
#  28  Gaze point left Y (MCSnorm)          26771 non-null  float64
#  29  Gaze point right X (MCSnorm)         26771 non-null  float64
#  30  Gaze point right Y (MCSnorm)         26771 non-null  float64
#  31  Presented Media width                26771 non-null  float64
#  32  Presented Media height               26771 non-null  float64
#  33  Presented Media position X (DACSpx)  26771 non-null  float64
#  34  Presented Media position Y (DACSpx)  26771 non-null  float64
#  35  Original Media width                 26771 non-null  float64
#  36  Original Media height                26771 non-null  float64
#  37  Gaze event duration                  26771 non-null  float64
#  38  Eye movement type index              26771 non-null  float64
#  39  Fixation point X                     26771 non-null  float64
#  40  Fixation point Y                     26771 non-null  float64
#  41  Fixation point X (MCSnorm)           26771 non-null  float64
#  42  Fixation point Y (MCSnorm)           26771 non-null  float64
#  43  Mouse position X                     26771 non-null  float64
#  44  Mouse position Y                     26771 non-null  float64
#  45  Participant_Number                   26771 non-null  int64
# dtypes: float64(45), int64(1)
# memory usage: 9.4 MB
# None
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8423 entries, 0 to 8422
# Data columns (total 46 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Recording timestamp                  8423 non-null   float64
#  1   Gaze point X                         8423 non-null   float64
#  2   Gaze point Y                         8423 non-null   float64
#  3   Gaze point left X                    8423 non-null   float64
#  4   Gaze point left Y                    8423 non-null   float64
#  5   Gaze point right X                   8423 non-null   float64
#  6   Gaze point right Y                   8423 non-null   float64
#  7   Gaze direction left X                8423 non-null   float64
#  8   Gaze direction left Y                8423 non-null   float64
#  9   Gaze direction left Z                8423 non-null   float64
#  10  Gaze direction right X               8423 non-null   float64
#  11  Gaze direction right Y               8423 non-null   float64
#  12  Gaze direction right Z               8423 non-null   float64
#  13  Pupil diameter left                  8423 non-null   float64
#  14  Pupil diameter right                 8423 non-null   float64
#  15  Eye position left X (DACSmm)         8423 non-null   float64
#  16  Eye position left Y (DACSmm)         8423 non-null   float64
#  17  Eye position left Z (DACSmm)         8423 non-null   float64
#  18  Eye position right X (DACSmm)        8423 non-null   float64
#  19  Eye position right Y (DACSmm)        8423 non-null   float64
#  20  Eye position right Z (DACSmm)        8423 non-null   float64
#  21  Gaze point left X (DACSmm)           8423 non-null   float64
#  22  Gaze point left Y (DACSmm)           8423 non-null   float64
#  23  Gaze point right X (DACSmm)          8423 non-null   float64
#  24  Gaze point right Y (DACSmm)          8423 non-null   float64
#  25  Gaze point X (MCSnorm)               8423 non-null   float64
#  26  Gaze point Y (MCSnorm)               8423 non-null   float64
#  27  Gaze point left X (MCSnorm)          8423 non-null   float64
#  28  Gaze point left Y (MCSnorm)          8423 non-null   float64
#  29  Gaze point right X (MCSnorm)         8423 non-null   float64
#  30  Gaze point right Y (MCSnorm)         8423 non-null   float64
#  31  Presented Media width                8423 non-null   float64
#  32  Presented Media height               8423 non-null   float64
#  33  Presented Media position X (DACSpx)  8423 non-null   float64
#  34  Presented Media position Y (DACSpx)  8423 non-null   float64
#  35  Original Media width                 8423 non-null   float64
#  36  Original Media height                8423 non-null   float64
#  37  Gaze event duration                  8423 non-null   float64
#  38  Eye movement type index              8423 non-null   float64
#  39  Fixation point X                     8423 non-null   float64
#  40  Fixation point Y                     8423 non-null   float64
#  41  Fixation point X (MCSnorm)           8423 non-null   float64
#  42  Fixation point Y (MCSnorm)           8423 non-null   float64
#  43  Mouse position X                     8423 non-null   float64
#  44  Mouse position Y                     8423 non-null   float64
#  45  Participant_Number                   8423 non-null   int64
# dtypes: float64(45), int64(1)
# memory usage: 3.0 MB
# None
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7512 entries, 0 to 7511
# Data columns (total 46 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Recording timestamp                  7512 non-null   float64
#  1   Gaze point X                         7512 non-null   float64
#  2   Gaze point Y                         7512 non-null   float64
#  3   Gaze point left X                    7512 non-null   float64
#  4   Gaze point left Y                    7512 non-null   float64
#  5   Gaze point right X                   7512 non-null   float64
#  6   Gaze point right Y                   7512 non-null   float64
#  7   Gaze direction left X                7512 non-null   float64
#  8   Gaze direction left Y                7512 non-null   float64
#  9   Gaze direction left Z                7512 non-null   float64
#  10  Gaze direction right X               7512 non-null   float64
#  11  Gaze direction right Y               7512 non-null   float64
#  12  Gaze direction right Z               7512 non-null   float64
#  13  Pupil diameter left                  7512 non-null   float64
#  14  Pupil diameter right                 7512 non-null   float64
#  15  Eye position left X (DACSmm)         7512 non-null   float64
#  16  Eye position left Y (DACSmm)         7512 non-null   float64
#  17  Eye position left Z (DACSmm)         7512 non-null   float64
#  18  Eye position right X (DACSmm)        7512 non-null   float64
#  19  Eye position right Y (DACSmm)        7512 non-null   float64
#  20  Eye position right Z (DACSmm)        7512 non-null   float64
#  21  Gaze point left X (DACSmm)           7512 non-null   float64
#  22  Gaze point left Y (DACSmm)           7512 non-null   float64
#  23  Gaze point right X (DACSmm)          7512 non-null   float64
#  24  Gaze point right Y (DACSmm)          7512 non-null   float64
#  25  Gaze point X (MCSnorm)               7512 non-null   float64
#  26  Gaze point Y (MCSnorm)               7512 non-null   float64
#  27  Gaze point left X (MCSnorm)          7512 non-null   float64
#  28  Gaze point left Y (MCSnorm)          7512 non-null   float64
#  29  Gaze point right X (MCSnorm)         7512 non-null   float64
#  30  Gaze point right Y (MCSnorm)         7512 non-null   float64
#  31  Presented Media width                7512 non-null   float64
#  32  Presented Media height               7512 non-null   float64
#  33  Presented Media position X (DACSpx)  7512 non-null   float64
#  34  Presented Media position Y (DACSpx)  7512 non-null   float64
#  35  Original Media width                 7512 non-null   float64
#  36  Original Media height                7512 non-null   float64
#  37  Gaze event duration                  7512 non-null   float64
#  38  Eye movement type index              7512 non-null   float64
#  39  Fixation point X                     7512 non-null   float64
#  40  Fixation point Y                     7512 non-null   float64
#  41  Fixation point X (MCSnorm)           7512 non-null   float64
#  42  Fixation point Y (MCSnorm)           7512 non-null   float64
#  43  Mouse position X                     7512 non-null   float64
#  44  Mouse position Y                     7512 non-null   float64
#  45  Participant_Number                   7512 non-null   int64
# dtypes: float64(45), int64(1)
# memory usage: 2.6 MB
# None
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8423 entries, 0 to 8422
# Data columns (total 46 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Recording timestamp                  8423 non-null   float64
#  1   Gaze point X                         8423 non-null   float64
#  2   Gaze point Y                         8423 non-null   float64
#  3   Gaze point left X                    8423 non-null   float64
#  4   Gaze point left Y                    8423 non-null   float64
#  5   Gaze point right X                   8423 non-null   float64
#  6   Gaze point right Y                   8423 non-null   float64
#  7   Gaze direction left X                8423 non-null   float64
#  8   Gaze direction left Y                8423 non-null   float64
#  9   Gaze direction left Z                8423 non-null   float64
#  10  Gaze direction right X               8423 non-null   float64
#  11  Gaze direction right Y               8423 non-null   float64
#  12  Gaze direction right Z               8423 non-null   float64
#  13  Pupil diameter left                  8423 non-null   float64
#  14  Pupil diameter right                 8423 non-null   float64
#  15  Eye position left X (DACSmm)         8423 non-null   float64
#  16  Eye position left Y (DACSmm)         8423 non-null   float64
#  17  Eye position left Z (DACSmm)         8423 non-null   float64
#  18  Eye position right X (DACSmm)        8423 non-null   float64
#  19  Eye position right Y (DACSmm)        8423 non-null   float64
#  20  Eye position right Z (DACSmm)        8423 non-null   float64
#  21  Gaze point left X (DACSmm)           8423 non-null   float64
#  22  Gaze point left Y (DACSmm)           8423 non-null   float64
#  23  Gaze point right X (DACSmm)          8423 non-null   float64
#  24  Gaze point right Y (DACSmm)          8423 non-null   float64
#  25  Gaze point X (MCSnorm)               8423 non-null   float64
#  26  Gaze point Y (MCSnorm)               8423 non-null   float64
#  27  Gaze point left X (MCSnorm)          8423 non-null   float64
#  28  Gaze point left Y (MCSnorm)          8423 non-null   float64
#  29  Gaze point right X (MCSnorm)         8423 non-null   float64
#  30  Gaze point right Y (MCSnorm)         8423 non-null   float64
#  31  Presented Media width                8423 non-null   float64
#  32  Presented Media height               8423 non-null   float64
#  33  Presented Media position X (DACSpx)  8423 non-null   float64
#  34  Presented Media position Y (DACSpx)  8423 non-null   float64
#  35  Original Media width                 8423 non-null   float64
#  36  Original Media height                8423 non-null   float64
#  37  Gaze event duration                  8423 non-null   float64
#  38  Eye movement type index              8423 non-null   float64
#  39  Fixation point X                     8423 non-null   float64
#  40  Fixation point Y                     8423 non-null   float64
#  41  Fixation point X (MCSnorm)           8423 non-null   float64
#  42  Fixation point Y (MCSnorm)           8423 non-null   float64
#  43  Mouse position X                     8423 non-null   float64
#  44  Mouse position Y                     8423 non-null   float64
#  45  Participant_Number                   8423 non-null   int64
# dtypes: float64(45), int64(1)
# memory usage: 3.0 MB
# None
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7446 entries, 0 to 7445
# Data columns (total 46 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Recording timestamp                  7446 non-null   float64
#  1   Gaze point X                         7446 non-null   float64
#  2   Gaze point Y                         7446 non-null   float64
#  3   Gaze point left X                    7446 non-null   float64
#  4   Gaze point left Y                    7446 non-null   float64
#  5   Gaze point right X                   7446 non-null   float64
#  6   Gaze point right Y                   7446 non-null   float64
#  7   Gaze direction left X                7446 non-null   float64
#  8   Gaze direction left Y                7446 non-null   float64
#  9   Gaze direction left Z                7446 non-null   float64
#  10  Gaze direction right X               7446 non-null   float64
#  11  Gaze direction right Y               7446 non-null   float64
#  12  Gaze direction right Z               7446 non-null   float64
#  13  Pupil diameter left                  7446 non-null   float64
#  14  Pupil diameter right                 7446 non-null   float64
#  15  Eye position left X (DACSmm)         7446 non-null   float64
#  16  Eye position left Y (DACSmm)         7446 non-null   float64
#  17  Eye position left Z (DACSmm)         7446 non-null   float64
#  18  Eye position right X (DACSmm)        7446 non-null   float64
#  19  Eye position right Y (DACSmm)        7446 non-null   float64
#  20  Eye position right Z (DACSmm)        7446 non-null   float64
#  21  Gaze point left X (DACSmm)           7446 non-null   float64
#  22  Gaze point left Y (DACSmm)           7446 non-null   float64
#  23  Gaze point right X (DACSmm)          7446 non-null   float64
#  24  Gaze point right Y (DACSmm)          7446 non-null   float64
#  25  Gaze point X (MCSnorm)               7446 non-null   float64
#  26  Gaze point Y (MCSnorm)               7446 non-null   float64
#  27  Gaze point left X (MCSnorm)          7446 non-null   float64
#  28  Gaze point left Y (MCSnorm)          7446 non-null   float64
#  29  Gaze point right X (MCSnorm)         7446 non-null   float64
#  30  Gaze point right Y (MCSnorm)         7446 non-null   float64
#  31  Presented Media width                7446 non-null   float64
#  32  Presented Media height               7446 non-null   float64
#  33  Presented Media position X (DACSpx)  7446 non-null   float64
#  34  Presented Media position Y (DACSpx)  7446 non-null   float64
#  35  Original Media width                 7446 non-null   float64
#  36  Original Media height                7446 non-null   float64
#  37  Gaze event duration                  7446 non-null   float64
#  38  Eye movement type index              7446 non-null   float64
#  39  Fixation point X                     7446 non-null   float64
#  40  Fixation point Y                     7446 non-null   float64
#  41  Fixation point X (MCSnorm)           7446 non-null   float64
#  42  Fixation point Y (MCSnorm)           7446 non-null   float64
#  43  Mouse position X                     7446 non-null   float64
#  44  Mouse position Y                     7446 non-null   float64
#  45  Participant_Number                   7446 non-null   int64
# dtypes: float64(45), int64(1)
# memory usage: 2.6 MB
# None
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# ...
#  16  Eye position left Y (DACSmm)         6207 non-null   float64
#  17  Eye position left Z (DACSmm)         6207 non-null   float64
#  18  Eye position right X (DACSmm)        6207 non-null   float64
#  19  Eye position right Y (DACSmm)        6207 non-null   float64
#  20  Eye position right Z (DACSmm)        6207 non-null   float64
#  21  Gaze point left X (DACSmm)           6207 non-null   float64
#  22  Gaze point left Y (DACSmm)           6207 non-null   float64
#  23  Gaze point right X (DACSmm)          6207 non-null   float64
#  24  Gaze point right Y (DACSmm)          6207 non-null   float64
#  25  Gaze point X (MCSnorm)               6207 non-null   float64
#  26  Gaze point Y (MCSnorm)               6207 non-null   float64
#  27  Gaze point left X (MCSnorm)          6207 non-null   float64
#  28  Gaze point left Y (MCSnorm)          6207 non-null   float64
#  29  Gaze point right X (MCSnorm)         6207 non-null   float64
#  30  Gaze point right Y (MCSnorm)         6207 non-null   float64
#  31  Presented Media width                6207 non-null   float64
#  32  Presented Media height               6207 non-null   float64
#  33  Presented Media position X (DACSpx)  6207 non-null   float64
#  34  Presented Media position Y (DACSpx)  6207 non-null   float64
#  35  Original Media width                 6207 non-null   float64
#  36  Original Media height                6207 non-null   float64
#  37  Gaze event duration                  6207 non-null   float64
#  38  Eye movement type index              6207 non-null   float64
#  39  Fixation point X                     6207 non-null   float64
#  40  Fixation point Y                     6207 non-null   float64
#  41  Fixation point X (MCSnorm)           6207 non-null   float64
#  42  Fixation point Y (MCSnorm)           6207 non-null   float64
#  43  Mouse position X                     6207 non-null   float64
#  44  Mouse position Y                     6207 non-null   float64
#  45  Participant_Number                   6207 non-null   int64
# dtypes: float64(45), int64(1)
# memory usage: 2.2 MB
# None
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7217 entries, 0 to 7216
# Data columns (total 46 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Recording timestamp                  7217 non-null   float64
#  1   Gaze point X                         7217 non-null   float64
#  2   Gaze point Y                         7217 non-null   float64
#  3   Gaze point left X                    7217 non-null   float64
#  4   Gaze point left Y                    7217 non-null   float64
#  5   Gaze point right X                   7217 non-null   float64
#  6   Gaze point right Y                   7217 non-null   float64
#  7   Gaze direction left X                7217 non-null   float64
#  8   Gaze direction left Y                7217 non-null   float64
#  9   Gaze direction left Z                7217 non-null   float64
#  10  Gaze direction right X               7217 non-null   float64
#  11  Gaze direction right Y               7217 non-null   float64
#  12  Gaze direction right Z               7217 non-null   float64
#  13  Pupil diameter left                  7217 non-null   float64
#  14  Pupil diameter right                 7217 non-null   float64
#  15  Eye position left X (DACSmm)         7217 non-null   float64
#  16  Eye position left Y (DACSmm)         7217 non-null   float64
#  17  Eye position left Z (DACSmm)         7217 non-null   float64
#  18  Eye position right X (DACSmm)        7217 non-null   float64
#  19  Eye position right Y (DACSmm)        7217 non-null   float64
#  20  Eye position right Z (DACSmm)        7217 non-null   float64
#  21  Gaze point left X (DACSmm)           7217 non-null   float64
#  22  Gaze point left Y (DACSmm)           7217 non-null   float64
#  23  Gaze point right X (DACSmm)          7217 non-null   float64
#  24  Gaze point right Y (DACSmm)          7217 non-null   float64
#  25  Gaze point X (MCSnorm)               7217 non-null   float64
#  26  Gaze point Y (MCSnorm)               7217 non-null   float64
#  27  Gaze point left X (MCSnorm)          7217 non-null   float64
#  28  Gaze point left Y (MCSnorm)          7217 non-null   float64
#  29  Gaze point right X (MCSnorm)         7217 non-null   float64
#  30  Gaze point right Y (MCSnorm)         7217 non-null   float64
#  31  Presented Media width                7217 non-null   float64
#  32  Presented Media height               7217 non-null   float64
#  33  Presented Media position X (DACSpx)  7217 non-null   float64
#  34  Presented Media position Y (DACSpx)  7217 non-null   float64
#  35  Original Media width                 7217 non-null   float64
#  36  Original Media height                7217 non-null   float64
#  37  Gaze event duration                  7217 non-null   float64
#  38  Eye movement type index              7217 non-null   float64
#  39  Fixation point X                     7217 non-null   float64
#  40  Fixation point Y                     7217 non-null   float64
#  41  Fixation point X (MCSnorm)           7217 non-null   float64
#  42  Fixation point Y (MCSnorm)           7217 non-null   float64
#  43  Mouse position X                     7217 non-null   float64
#  44  Mouse position Y                     7217 non-null   float64
#  45  Participant_Number                   7217 non-null   int64
# dtypes: float64(45), int64(1)
# memory usage: 2.5 MB
# None
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7233 entries, 0 to 7232
# Data columns (total 46 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Recording timestamp                  7233 non-null   float64
#  1   Gaze point X                         7233 non-null   float64
#  2   Gaze point Y                         7233 non-null   float64
#  3   Gaze point left X                    7233 non-null   float64
#  4   Gaze point left Y                    7233 non-null   float64
#  5   Gaze point right X                   7233 non-null   float64
#  6   Gaze point right Y                   7233 non-null   float64
#  7   Gaze direction left X                7233 non-null   float64
#  8   Gaze direction left Y                7233 non-null   float64
#  9   Gaze direction left Z                7233 non-null   float64
#  10  Gaze direction right X               7233 non-null   float64
#  11  Gaze direction right Y               7233 non-null   float64
#  12  Gaze direction right Z               7233 non-null   float64
#  13  Pupil diameter left                  7233 non-null   float64
#  14  Pupil diameter right                 7233 non-null   float64
#  15  Eye position left X (DACSmm)         7233 non-null   float64
#  16  Eye position left Y (DACSmm)         7233 non-null   float64
#  17  Eye position left Z (DACSmm)         7233 non-null   float64
#  18  Eye position right X (DACSmm)        7233 non-null   float64
#  19  Eye position right Y (DACSmm)        7233 non-null   float64
#  20  Eye position right Z (DACSmm)        7233 non-null   float64
#  21  Gaze point left X (DACSmm)           7233 non-null   float64
#  22  Gaze point left Y (DACSmm)           7233 non-null   float64
#  23  Gaze point right X (DACSmm)          7233 non-null   float64
#  24  Gaze point right Y (DACSmm)          7233 non-null   float64
#  25  Gaze point X (MCSnorm)               7233 non-null   float64
#  26  Gaze point Y (MCSnorm)               7233 non-null   float64
#  27  Gaze point left X (MCSnorm)          7233 non-null   float64
#  28  Gaze point left Y (MCSnorm)          7233 non-null   float64
#  29  Gaze point right X (MCSnorm)         7233 non-null   float64
#  30  Gaze point right Y (MCSnorm)         7233 non-null   float64
#  31  Presented Media width                7233 non-null   float64
#  32  Presented Media height               7233 non-null   float64
#  33  Presented Media position X (DACSpx)  7233 non-null   float64
#  34  Presented Media position Y (DACSpx)  7233 non-null   float64
#  35  Original Media width                 7233 non-null   float64
#  36  Original Media height                7233 non-null   float64
#  37  Gaze event duration                  7233 non-null   float64
#  38  Eye movement type index              7233 non-null   float64
#  39  Fixation point X                     7233 non-null   float64
#  40  Fixation point Y                     7233 non-null   float64
#  41  Fixation point X (MCSnorm)           7233 non-null   float64
#  42  Fixation point Y (MCSnorm)           7233 non-null   float64
#  43  Mouse position X                     7233 non-null   float64
#  44  Mouse position Y                     7233 non-null   float64
#  45  Participant_Number                   7233 non-null   int64
# dtypes: float64(45), int64(1)
# memory usage: 2.5 MB
# None
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# C:\Users\Zain Ali\AppData\Local\Temp\ipykernel_24152\61554877.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   participant_data = participant_data.append(modes.iloc[0], ignore_index=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7310 entries, 0 to 7309
# Data columns (total 46 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Recording timestamp                  7310 non-null   float64
#  1   Gaze point X                         7310 non-null   float64
#  2   Gaze point Y                         7310 non-null   float64
#  3   Gaze point left X                    7310 non-null   float64
#  4   Gaze point left Y                    7310 non-null   float64
#  5   Gaze point right X                   7310 non-null   float64
#  6   Gaze point right Y                   7310 non-null   float64
#  7   Gaze direction left X                7310 non-null   float64
#  8   Gaze direction left Y                7310 non-null   float64
#  9   Gaze direction left Z                7310 non-null   float64
#  10  Gaze direction right X               7310 non-null   float64
#  11  Gaze direction right Y               7310 non-null   float64
#  12  Gaze direction right Z               7310 non-null   float64
#  13  Pupil diameter left                  7310 non-null   float64
#  14  Pupil diameter right                 7310 non-null   float64
#  15  Eye position left X (DACSmm)         7310 non-null   float64
#  16  Eye position left Y (DACSmm)         7310 non-null   float64
#  17  Eye position left Z (DACSmm)         7310 non-null   float64
#  18  Eye position right X (DACSmm)        7310 non-null   float64
#  19  Eye position right Y (DACSmm)        7310 non-null   float64
#  20  Eye position right Z (DACSmm)        7310 non-null   float64
#  21  Gaze point left X (DACSmm)           7310 non-null   float64
#  22  Gaze point left Y (DACSmm)           7310 non-null   float64
#  23  Gaze point right X (DACSmm)          7310 non-null   float64
#  24  Gaze point right Y (DACSmm)          7310 non-null   float64
#  25  Gaze point X (MCSnorm)               7310 non-null   float64
#  26  Gaze point Y (MCSnorm)               7310 non-null   float64
#  27  Gaze point left X (MCSnorm)          7310 non-null   float64
#  28  Gaze point left Y (MCSnorm)          7310 non-null   float64
#  29  Gaze point right X (MCSnorm)         7310 non-null   float64
#  30  Gaze point right Y (MCSnorm)         7310 non-null   float64
#  31  Presented Media width                7310 non-null   float64
#  32  Presented Media height               7310 non-null   float64
#  33  Presented Media position X (DACSpx)  7310 non-null   float64
#  34  Presented Media position Y (DACSpx)  7310 non-null   float64
#  35  Original Media width                 7310 non-null   float64
#  36  Original Media height                7310 non-null   float64
#  37  Gaze event duration                  7310 non-null   float64
#  38  Eye movement type index              7310 non-null   float64
#  39  Fixation point X                     7310 non-null   float64
#  40  Fixation point Y                     7310 non-null   float64
#  41  Fixation point X (MCSnorm)           7310 non-null   float64
#  42  Fixation point Y (MCSnorm)           7310 non-null   float64
#  43  Mouse position X                     7310 non-null   float64
#  44  Mouse position Y                     7310 non-null   float64
#  45  Participant_Number                   7310 non-null   int64
# dtypes: float64(45), int64(1)
# memory usage: 2.6 MB
# None
